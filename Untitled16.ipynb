# %% [markdown]
# <a href="https://colab.research.google.com/github/kshitijsharma37/NightTimeLight/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ipyleaflet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install earthengine-api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# reminder that if you are installing libraries in a Google Colab instance you will be prompted to restart your kernal

try:
    import geemap, ee
    import seaborn as sns
    import matplotlib.pyplot as plt
except ModuleNotFoundError:
    if 'google.colab' in str(get_ipython()):
        print("package not found, installing w/ pip in Google Colab...")
        # !pip install geemap seaborn matplotlib
    else:
        print("package not found, installing w/ conda...")
        # !conda install mamba -c conda-forge -y
        # !mamba install geemap -c conda-forge -y
        # !conda install seaborn matplotlib -y
    import geemap, ee
    import seaborn as sns
    import matplotlib.pyplot as plt

# %%
try:
        ee.Initialize()
except Exception as e:
        ee.Authenticate()
        ee.Initialize()

viirs = ee.ImageCollection("NOAA/VIIRS/DNB/MONTHLY_V1/VCMSLCFG").select('avg_rad')

# %%
#select_cities = ['Pune', 'Nagpur', 'Kolhapur']
select_cities = ['Mumbai city', 'Mumbai Suburban', 'Ahmednagar', 'Akola', 'Amravati', 'Bhandara', 'Bid', 'Buldana', 'Chandrapur', 'Dhule', 'Gondiya', 'Hingoli', 'Jalgaon', 'Jalna' ,'Kolhapur', 'Latur', 'Nagpur', 'Nanded', 'Nandurbar', 'Nashik', 'Osmanabad', 'Parbhani', 'Pune', 'Ratnagiri', 'Sangli', 'Satara', 'Sindhudurg', 'Solapur', 'Thane', 'Wardha', 'Washim', 'Yavatmal']
select_cities1 = ['Ahmednagar', 'Akola', 'Amravati', 'Aurangabad', 'Beed', 'Bhandara', 'Buldhana', 'Chandrapur', 'Dhule', 'Gadchiroli', 'Gondia', 'Hingoli', 'Jalgaon', 'Jalna', 'Kolhapur', 'Latur', 'Nagpur', 'Nanded', 'Nandurbar', 'Nashik', 'Osmanabad', 'Palghar', 'Parbhani', 'Pune', 'Raigad', 'Ratnagiri', 'Sangli', 'Satara', 'Sindhudurg', 'Solapur', 'Thane', 'Wardha', 'Washim', 'Yavatmal']
select_cities2 = []
excluded = ['Aurangabad', 'Gadchiroli', 'Palghar', 'Raigad']
city_geoms = ee.FeatureCollection("FAO/GAUL/2015/level2").filter(ee.Filter.inList('ADM2_NAME', select_cities))
print(len(select_cities))
# Out:
# 32

# %%
# function to reduce our collection of geometries
def get_city_avg_rad(img):
    return img.reduceRegions(reducer=ee.Reducer.mean(), collection=city_geoms, scale=500)

# function to get individual img dates
def get_date(img):
    return img.set('date', img.date().format())

# map these functions to our image collection
reduced_cities = viirs.map(get_city_avg_rad).flatten()
dates = viirs.map(get_date)

# get lists
key_cols = ['ADM2_NAME','mean']
cities_list = reduced_cities.reduceColumns(ee.Reducer.toList(len(key_cols)), key_cols).values()
dates_list = dates.reduceColumns(ee.Reducer.toList(1), ['date']).values()

# some numpy maneuvers to structure our data
df = pd.DataFrame(np.asarray(cities_list.getInfo()).squeeze(), columns=key_cols)
dates = np.asarray(dates_list.getInfo()).squeeze()

for city in select_cities:
    df.loc[df['ADM2_NAME']==city,'dates'] = dates
    
# as we've done before, convert date and set index
df['dates'] = pd.to_datetime(df['dates'])
df.set_index('dates', inplace=True)

# we'll also convert our mean datatype to float
df['mean'] = df['mean'].astype(float)

# %%
df
# Out:
#                   ADM2_NAME       mean
# dates
# 2014-01-01        Nandurbar   0.303747
# 2014-01-01            Akola   0.555654
# 2014-01-01         Amravati   0.470081
# 2014-01-01         Bhandara   0.258220
# 2014-01-01          Buldana   0.360416
# ...                     ...        ...
# 2022-05-01            Jalna   1.205721
# 2022-05-01  Mumbai Suburban  24.874020
# 2022-05-01      Mumbai city  44.184119
# 2022-05-01         Parbhani   1.155752
# 2022-05-01           Washim   0.882984
#
# [3232 rows x 2 columns]

# %%
# !pip install geemap geopandas

# %%
import json
import geopandas as gpd
import geemap

# %%
# location of shapefile locally
aurangabad_shp_path = '/content/sample_data/aurangabad/aurangabad.shp'
gadchiroli_shp_path = '/content/sample_data/gadchiroli/gadchiroli.shp'
palghar_shp_path = '/content/sample_data/palghar/palghar.shp'
raigad_shp_path = '/content/sample_data/raigad/raigad.shp'

# we read our shapefile in to a geopandas data frame using the geopandas.read_file method
# we'll make sure it's initiated in the EPSG 4326 CRS
aurangabad_gdf = gpd.read_file(aurangabad_shp_path, crs='EPSG:4326')
gadchiroli_gdf = gpd.read_file(gadchiroli_shp_path, crs='EPSG:4326')
palghar_gdf = gpd.read_file(palghar_shp_path, crs='EPSG:4326')
raigad_gdf = gpd.read_file(raigad_shp_path, crs='EPSG:4326')

# define a helper function to put the geodataframe in the right format for constructing an ee object
def shp_to_ee_fmt(geodf):
    data = json.loads(geodf.to_json())
    return data['features'][0]['geometry']['coordinates']

# create the ee object
aurangabad = ee.Geometry.MultiPolygon(shp_to_ee_fmt(aurangabad_gdf))
gadchiroli = ee.Geometry.MultiPolygon(shp_to_ee_fmt(gadchiroli_gdf))
palghar = ee.Geometry.MultiPolygon(shp_to_ee_fmt(palghar_gdf))
raigad = ee.Geometry.MultiPolygon(shp_to_ee_fmt(raigad_gdf))

# %%
excluded_geoms1 = [ee.Feature(aurangabad, {'ADM2_NAME' : 'Aurangabad'}), ee.Feature(gadchiroli, {'ADM2_NAME' : 'Gadchiroli'}), ee.Feature(palghar, {'ADM2_NAME' : 'Palghar'}), ee.Feature(raigad, {'ADM2_NAME' : 'Raigad'})]

# %%
excluded_geoms = ee.FeatureCollection(excluded_geoms1)

# %%
# function to reduce our collection of geometries
def get_city_avg_rad1(img):
    return img.reduceRegions(reducer=ee.Reducer.mean(), collection=excluded_geoms, scale=500)

# function to get individual img dates
def get_date1(img):
    return img.set('date', img.date().format())

# map these functions to our image collection
reduced_cities1 = viirs.map(get_city_avg_rad1).flatten()
dates1 = viirs.map(get_date1)

# get lists
key_cols1 = ['ADM2_NAME','mean']
cities_list1 = reduced_cities1.reduceColumns(ee.Reducer.toList(len(key_cols)), key_cols).values()
dates_list1 = dates1.reduceColumns(ee.Reducer.toList(1), ['date']).values()

# some numpy maneuvers to structure our data
data = pd.DataFrame(np.asarray(cities_list1.getInfo()).squeeze(), columns=key_cols)
dates1 = np.asarray(dates_list1.getInfo()).squeeze()

data
# Out:
#       ADM2_NAME                 mean
# 0    Aurangabad   0.2149842223214225
# 1    Gadchiroli  0.08320151828483194
# 2       Palghar   0.9306770735615328
# 3        Raigad    4.066693551547815
# 4    Aurangabad   0.3267845382061472
# ..          ...                  ...
# 399      Raigad   5.4124180915389175
# 400  Aurangabad     1.16599386158165
# 401  Gadchiroli   0.6185217982092084
# 402     Palghar   1.9169635713756765
# 403      Raigad    5.002020256381699
#
# [404 rows x 2 columns]

# %%
for city in excluded:
    data.loc[data['ADM2_NAME']==city,'dates'] = dates

data
# Out:
#       ADM2_NAME                 mean                dates               dates1
# 0    Aurangabad   0.2149842223214225  2014-01-01T00:00:00  2014-01-01T00:00:00
# 1    Gadchiroli  0.08320151828483194  2014-01-01T00:00:00  2014-01-01T00:00:00
# 2       Palghar   0.9306770735615328  2014-01-01T00:00:00  2014-01-01T00:00:00
# 3        Raigad    4.066693551547815  2014-01-01T00:00:00  2014-01-01T00:00:00
# 4    Aurangabad   0.3267845382061472  2014-02-01T00:00:00  2014-02-01T00:00:00
# ..          ...                  ...                  ...                  ...
# 399      Raigad   5.4124180915389175  2022-04-01T00:00:00  2022-04-01T00:00:00
# 400  Aurangabad     1.16599386158165  2022-05-01T00:00:00  2022-05-01T00:00:00
# 401  Gadchiroli   0.6185217982092084  2022-05-01T00:00:00  2022-05-01T00:00:00
# 402     Palghar   1.9169635713756765  2022-05-01T00:00:00  2022-05-01T00:00:00
# 403      Raigad    5.002020256381699  2022-05-01T00:00:00  2022-05-01T00:00:00
#
# [404 rows x 4 columns]

# %%
# as we've done before, convert date and set index
data['dates'] = pd.to_datetime(df['dates'])
data.set_index('dates', inplace=True)

# we'll also convert our mean datatype to float
data['mean'] = data['mean'].astype(float)
